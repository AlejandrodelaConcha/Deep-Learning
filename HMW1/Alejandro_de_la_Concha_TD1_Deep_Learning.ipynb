# %% [markdown]
# <a href="https://colab.research.google.com/github/AlejandrodelaConcha/Deep-Learning/blob/master/Alejandro_de_la_Concha_TD1_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os

path=os.path.dirname(os.getcwd())
sys.path.append(path)
import matplotlib.pyplot as plt
#%matplotlib inline
import numpy as np
from keras.utils import np_utils
import copy
# On some implementations of matplotlib, you may need to change this value
IMAGE_SIZE = 72

def generate_a_drawing(figsize, U, V, noise=0.0):
    fig = plt.figure(figsize=(figsize,figsize))
    ax = plt.subplot(111)
    plt.axis('Off')
    ax.set_xlim(0,figsize)
    ax.set_ylim(0,figsize)
    ax.fill(U, V, "k")
    fig.canvas.draw()
    imdata = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)[::3].astype(np.float32)
    imdata = imdata + noise * np.random.random(imdata.size)
    plt.close(fig)
    return imdata

def generate_a_rectangle(noise=0.0, free_location=False):
    figsize = 1.0    
    U = np.zeros(4)
    V = np.zeros(4)
    if free_location:
        corners = np.random.random(4)
        top = max(corners[0], corners[1])
        bottom = min(corners[0], corners[1])
        left = min(corners[2], corners[3])
        right = max(corners[2], corners[3])
    else:
        side = (0.3 + 0.7 * np.random.random()) * figsize
        top = figsize/2 + side/2
        bottom = figsize/2 - side/2
        left = bottom
        right = top
    U[0] = U[1] = top
    U[2] = U[3] = bottom
    V[0] = V[3] = left
    V[1] = V[2] = right
    return generate_a_drawing(figsize, U, V, noise)

def generate_rectangles(noise=0.0, free_location=False):
    figsize = 1.0    
    U = np.zeros(4)
    V = np.zeros(4)
    if free_location:
        corners = np.random.random(4)
        top = max(corners[0], corners[1])
        bottom = min(corners[0], corners[1])
        left = min(corners[2], corners[3])
        right = max(corners[2], corners[3])
    else:
        side = (0.3 + 0.7 * np.random.random()) * figsize
        top = figsize/2 + side/2
        bottom = figsize/2 - side/2
        left = bottom
        right = top
    U[0] = U[1] = top
    U[2] = U[3] = bottom
    V[0] = V[3] = left
    V[1] = V[2] = right
    return [generate_a_drawing(figsize, U, V,noise),generate_a_drawing(figsize, U, V,0)]


def generate_a_disk(noise=0.0, free_location=False):
    figsize = 1.0
    if free_location:
        center = np.random.random(2)
    else:
        center = (figsize/2, figsize/2)
    radius = (0.3 + 0.7 * np.random.random()) * figsize/2
    N = 50
    U = np.zeros(N)
    V = np.zeros(N)
    i = 0
    for t in np.linspace(0, 2*np.pi, N):
        U[i] = center[0] + np.cos(t) * radius
        V[i] = center[1] + np.sin(t) * radius
        i = i + 1
    return generate_a_drawing(figsize, U, V, noise)

def generate_disks(noise=0.0, free_location=False):
    figsize = 1.0
    if free_location:
        center = np.random.random(2)
    else:
        center = (figsize/2, figsize/2)
    radius = (0.3 + 0.7 * np.random.random()) * figsize/2
    N = 50
    U = np.zeros(N)
    V = np.zeros(N)
    i = 0
    for t in np.linspace(0, 2*np.pi, N):
        U[i] = center[0] + np.cos(t) * radius
        V[i] = center[1] + np.sin(t) * radius
        i = i + 1
    return [generate_a_drawing(figsize, U, V,noise),generate_a_drawing(figsize, U, V,0)]

def generate_a_triangle(noise=0.0, free_location=False):
    figsize = 1.0
    if free_location:
        U = np.random.random(3)
        V = np.random.random(3)
    else:
        size = (0.3 + 0.7 * np.random.random())*figsize/2
        middle = figsize/2
        U = (middle, middle+size, middle-size)
        V = (middle+size, middle-size, middle-size)
    imdata = generate_a_drawing(figsize, U, V, noise)
    return [imdata, [U[0], V[0], U[1], V[1], U[2], V[2]]]

def generate_triangles(noise=0.0, free_location=False):
    figsize = 1.0
    if free_location:
        U = np.random.random(3)
        V = np.random.random(3)
    else:
        size = (0.3 + 0.7 * np.random.random())*figsize/2
        middle = figsize/2
        U = (middle, middle+size, middle-size)
        V = (middle+size, middle-size, middle-size)
    imdata= generate_a_drawing(figsize, U, V, 0)
    imdata_noisy= generate_a_drawing(figsize, U, V, noise)
    return [imdata_noisy,imdata,  [U[0], V[0], U[1], V[1], U[2], V[2]]]


#im = generate_a_rectangle(10, True)
#plt.imshow(im.reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')

#im = generate_a_disk(10)
#plt.imshow(im.reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')

#[im, v] = generate_a_triangle(20, False)
#plt.imshow(im.reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')


def generate_dataset_classification(nb_samples, noise=0.0, free_location=False,verbose=True):
    # Getting im_size:
    im_size = generate_a_rectangle().shape[0]
    X = np.zeros([nb_samples,im_size])
    Y = np.zeros(nb_samples)
    print('Creating data:')
    for i in range(nb_samples):
        if i % 10 == 0:
            if(verbose):
                print(i)
        category = np.random.randint(3)
        if category == 0:
            X[i] = generate_a_rectangle(noise, free_location)
        elif category == 1: 
            X[i] = generate_a_disk(noise, free_location)
        else:
            [X[i], V] = generate_a_triangle(noise, free_location)
        Y[i] = category
    X = (X + noise) / (255 + 2 * noise)
    return [X, Y]


def generate_test_set_classification(free_location=False,verbose=True):
    np.random.seed(42)
    [X_test, Y_test] = generate_dataset_classification(300, 20, free_location,verbose)
    Y_test = np_utils.to_categorical(Y_test, 3) 
    return [X_test, Y_test]

def generate_dataset_regression(nb_samples, noise=0.0,free_location=True,verbose=True):
    # Getting im_size:
    im_size = generate_a_triangle()[0].shape[0]
    X = np.zeros([nb_samples,im_size])
    Y = np.zeros([nb_samples, 6])
    print('Creating data:')
    for i in range(nb_samples):
        if i % 10 == 0:
            if verbose:
                print(i)
        [X[i], Y[i]] = generate_a_triangle(noise, free_location)
    X = (X + noise) / (255 + 2 * noise)
    return [X, Y]

import matplotlib.patches as patches

def visualize_prediction(x, y):
    fig, ax = plt.subplots(figsize=(5, 5))
    I = x.reshape((IMAGE_SIZE,IMAGE_SIZE))
    ax.imshow(I, extent=[-0.15,1.15,-0.15,1.15],cmap='gray')
    ax.set_xlim([0,1])
    ax.set_ylim([0,1])

    xy = y.reshape(3,2)
    tri = patches.Polygon(xy, closed=True, fill = False, edgecolor = 'r', linewidth = 5, alpha = 0.5)
    ax.add_patch(tri)

    plt.show()
    

def generate_test_set_regression(free_location=True,verbose=False):
    np.random.seed(42)
    [X_test, Y_test] = generate_dataset_regression(300, 20,free_location,verbose=False)
    return [X_test, Y_test]


def generate_dataset_denoising(nb_samples, noise=0.0, free_location=False,verbose=True):
    # Getting im_size:
    im_size = generate_a_rectangle().shape[0]
    X = np.zeros([nb_samples,im_size])
    Y = np.zeros([nb_samples,im_size])
    print('Creating data:')
    for i in range(nb_samples):
        if i % 10 == 0:
            if verbose:
                print(i)
        category = np.random.randint(3)
        if category == 0:
            [X[i],Y[i]] = generate_rectangles(noise, free_location)
        elif category == 1: 
            [X[i],Y[i]]= generate_disks(noise, free_location)
        else:
            [X[i],Y[i], V] = generate_triangles(noise, free_location)
    
    X = (X  + noise)/ (255 + 2 * noise)    
    Y = (Y) / (255)
    return [X, Y]

def generate_test_set_denoising(verbose=True):
    np.random.seed(42)
    [X_test, Y_test] = generate_dataset_denoising(300, 20,True,verbose)
    return [X_test, Y_test]

def compute_angles(Y):
    Y=Y+1
    first_vector_1=Y[[2,3]]-Y[[0,1]]
    second_vector_1=Y[[4,5]]-Y[[0,1]]
    cos_1= first_vector_1.dot(second_vector_1)/(np.sqrt(np.dot(first_vector_1,first_vector_1))*np.sqrt(np.dot(second_vector_1,second_vector_1)))
    theta_1=np.arccos(cos_1)

    first_vector_2=Y[[0,1]]-Y[[2,3]]
    second_vector_2=Y[[4,5]]-Y[[2,3]]
    cos_2= first_vector_2.dot(second_vector_2)/(np.sqrt(np.dot(first_vector_2,first_vector_2))*np.sqrt(np.dot(second_vector_2,second_vector_2)))
    theta_2=np.arccos(cos_2)

    first_vector_3=Y[[0,1]]-Y[[4,5]]
    second_vector_3=Y[[2,3]]-Y[[4,5]]
    cos_3= first_vector_3.dot(second_vector_3)/(np.sqrt(np.dot(first_vector_3,first_vector_3))*np.sqrt(np.dot(second_vector_3,second_vector_3)))
    theta_3=np.arccos(cos_3)

    return(np.array([theta_1,theta_2,theta_3]))
    
def order_by_angles(Y):
    Y_ordered=copy.deepcopy(Y)
    if(len(Y.shape)>1):
        for i in range(Y.shape[0]):
            thetas=compute_angles(Y[i])
            first_point=np.argsort(thetas)
            Y_ordered[i][[0,2,4]]=Y[i][[0,2,4]][first_point]
            Y_ordered[i][[1,3,5]]=Y[i][[1,3,5]][first_point]
    else:
        thetas=compute_angles(Y)
        first_point=np.argsort(thetas)
        Y_ordered[[0,2,4]]=Y[[0,2,4]][first_point]
        Y_ordered[[1,3,5]]=Y[[1,3,5]][first_point]
    return(Y_ordered)
    


from keras.models import Sequential,Model,load_model
from keras.layers import Dense,Dropout,Input,Flatten,Conv2D, MaxPooling2D,UpSampling2D,merge,concatenate,BatchNormalization
from keras.utils import np_utils
from keras import optimizers,layers
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Simple Classification

# %% [markdown]
# I generated a dataset with 300 observtions.

# %%
[X_train, Y_train] = generate_dataset_classification(300, 20,verbose=False) ### I add verbose to not see the number of points
Y_train=np_utils.to_categorical(Y_train)
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1])
# Out:
# Creating data:

# %% [markdown]
# As the first task is classification, the problem suggests to create a linear classifier that will be equivalent to just have a layer representing the three classes with softmax as activation function. The loss function used in the problem was cross entropy.
#
# I trained 3 different models with different optimizers. The goal is to compare ADAM vs the Stochastic Gradient Descent (SGD) as indicated in the HW. The three models were trained by using 100 epochs. For the ADAM model I used a batch size of 32, for the SG a learning rate of 0.1 and 0.001. Aditionally, I analyzed the modified SGD with a momentum of 0.9.

# %%
################# ADAM

model_ADAM=Sequential()
model_ADAM.add(Dense(3,activation="softmax",input_shape=(X_train.shape[1],)))
model_ADAM.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])
evolution_ADAM=model_ADAM.fit(X_train,Y_train,
          batch_size=32,epochs=100,verbose=0)

################# SGD 1 with lr=0.01

model_SGD_1=Sequential()
model_SGD_1.add(Dense(3,activation="softmax",input_shape=(X_train.shape[1],)))
sgd = optimizers.SGD()
model_SGD_1.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])
evolution_SGD_1=model_SGD_1.fit(X_train,Y_train,epochs=100,verbose=0)

################# SGD with lr=0.001

model_SGD_2=Sequential()
model_SGD_2.add(Dense(3,activation="softmax",input_shape=(X_train.shape[1],)))
sgd = optimizers.SGD(lr=0.001)
model_SGD_2.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])
evolution_SGD_2=model_SGD_2.fit(X_train,Y_train,epochs=100,verbose=0)

################# SGD 3 with lr=0.001 and momentum=0.9

model_SGD_3=Sequential()
model_SGD_3.add(Dense(3,activation="softmax",input_shape=(X_train.shape[1],)))
sgd = optimizers.SGD(lr=0.001,momentum=0.9)
model_SGD_3.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])
evolution_SGD_3=model_SGD_3.fit(X_train,Y_train,epochs=100,verbose=0)

# %% [markdown]
# I generate the test set to compare the models.

# %%
[X_test, Y_test]=generate_test_set_classification(verbose=False)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1])
# Out:
# Creating data:

# %% [markdown]
# We can see in the figure bellow how the ADAM optimizer converged faster compared with the SGD without momentum. In fact, in practice, the ADAM optimizer is commonly preferred.
# Additionally, we can see the sensitivity of the SGD to the learning rate. A bad value of the learning rate can lead to poor results as the orange line indicates.
# In this example, we can see how adding the momentum parameter can improve a lot the performance of the SGD optimizer by allowing it to scape from saddle points.
# As we saw in the lectures, in general, the choice of the optimizer depends more on our knowledge of how to modify the parameters.

# %%
plt.figure(figsize=(25,10))
plt.plot(evolution_ADAM.history['acc'])
plt.plot(evolution_SGD_1.history['acc'])
plt.plot(evolution_SGD_2.history['acc'])
plt.plot(evolution_SGD_3.history['acc'])
plt.legend(['Adam', 'SGD with lr=0.01',"SGD with lr=0.001","SGD with lr=0.001 and momentum=0.9"], loc='upper left')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %% [markdown]
# When we valuate the models in a test set, I found an accuracy of $99.6%$ for the SGD with momentum. The ADAM optimizer gets a smaller value for the loss function an accuracy of $100\%$. In this example, I would choose the ADMA

# %%
print("ADAM "+str(model_ADAM.evaluate(X_test,Y_test,verbose=0)))
print('SGD with lr=0.01 '+str(model_SGD_1.evaluate(X_test,Y_test,verbose=0)))
print("SGD with lr=0.001 "+str(model_SGD_2.evaluate(X_test,Y_test,verbose=0)))
print("SGD with lr=0.001 and momentum=0.9 "+str(model_SGD_3.evaluate(X_test,Y_test,verbose=0)))
# Out:
# ADAM [0.009042827195177476, 1.0]
# SGD with lr=0.01 [10.530488878885905, 0.346666667064031]
# SGD with lr=0.001 [0.21741157909234365, 0.9200000007947285]
# SGD with lr=0.001 and momentum=0.9 [0.032271040380001066, 1.0]

# %% [markdown]
# # Visualization of the solution

# %% [markdown]
# The figures below show the weights of the links that go from each pixel to each category. The categories are rectangle, disk and triangle, in that order. I compared the ADAM and the SGD with momentum models. The darker the pixer the bigger the value of the weight of the pixel in the soft-max function of the corresponding category.
#
# These figures give us an intuition about what features the NN is stracting from the data to classify yhe images.In both models, we can see a rectangle and a triangle detector. For the remainning figures, the results are not clear. It is interesting how, even in a easy task is difficult to interpret what a nn is doing.
#
# Nevertheless, in both models, the three figures are different showing that the soft-max functions ponderate differently the pixels accordind to the figure they train to predict.

# %%
IMAGE_SIZE=72
cl0=model_SGD_3.get_weights()[0][:,0]
cl1=model_SGD_3.get_weights()[0][:,1]
cl2=model_SGD_3.get_weights()[0][:,2]

plt.subplot(1, 3, 1)
plt.imshow(cl0.reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
plt.subplot(1, 3, 2)
plt.imshow(cl1.reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(cl2.reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
plt.show()

# %%
IMAGE_SIZE=72
cl0=model_ADAM.get_weights()[0][:,0]
cl1=model_ADAM.get_weights()[0][:,1]
cl2=model_ADAM.get_weights()[0][:,2]

plt.subplot(1, 3, 1)
plt.imshow(cl0.reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
plt.subplot(1, 3, 2)
plt.imshow(cl1.reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(cl2.reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
plt.show()

# %% [markdown]
# # A more difficult classification problem.

# %% [markdown]
# In this part, once again, I tried to predict the cluster of each observation, but this time the position and orientation of the figures change. I tried multiple models with relu and softmax as activation functions. In all cases I use the crossentropy as loss function.I show here the results for the model suggested in the HW without any regulization and another model with regularization and an extra fully connected network.

# %% [markdown]
# I generated 1000 samples of the train set as I see that the models had problems to generalize with only 300.

# %%
[X_train, Y_train] = generate_dataset_classification(1000, 20, True, verbose=False)
X_train=X_train.reshape(X_train.shape[0],72,72,1)
Y_train=np_utils.to_categorical(Y_train)
# Out:
# Creating data:

# %% [markdown]
# Suggested model in the HW: 1 convolutional layer with 16 5x5 flters, 1 pooling layer, and one fully connected layer.

# %%
model_suggested=Sequential()
model_suggested.add(Conv2D(16,(5,5),activation="relu",input_shape=(72,72,1)))
model_suggested.add(MaxPooling2D(pool_size=(3,3)))
model_suggested.add(Flatten())
model_suggested.add(Dense(3,activation="softmax"))
model_suggested.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])
model_suggested.fit(X_train,Y_train,
          batch_size=32,epochs=100,verbose=0)

# %% [markdown]
# Model that improves results (model 2) : Suggested model in the HW: 1 convolutional layer with 16 5x5 flters, 1 pooling layer, and two fully connected layer and with dropout to avoid overfiting

# %%
model_2=Sequential()
model_2.add(Conv2D(16,(5,5),activation="relu",input_shape=(72,72,1)))
model_2.add(MaxPooling2D(pool_size=(3,3)))
model_2.add(Dropout(0.25))
model_2.add(MaxPooling2D(pool_size=(3,3)))
model_2.add(Dropout(0.25))
model_2.add(Flatten())
model_2.add(Dense(128,activation="relu"))
model_2.add(Dropout(0.5))
model_2.add(Dense(3,activation="softmax"))
model_2.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])
model_2.fit(X_train,Y_train,
          batch_size=32,epochs=100,verbose=0)

# %% [markdown]
# I generated a test set to compare both models.

# %%
[X_test, Y_test]=generate_test_set_classification(True,verbose=False)
X_test=X_test.reshape(X_test.shape[0],72,72,1)
# Out:
# Creating data:

# %% [markdown]
# After training the suggested model, I realized that the difference between the accuracy in the train and test set was big showing overfitting.
# A way to avoid this is to use regularization, for that reason in model 2 I add dropout, that is in the training , the algorithm eliminate some paths with a given probability. I also added a layer. This improved considerable the model as we can see: going from an accuracy of $87\%$ to an accuracy of $95\%$ in the test set. We can see how the gap between the accuracies in model 2 is smaller showing a smaller degree of overfitting.

# %%
print("Model suggested in train set "+str(model_suggested.evaluate(X_train,Y_train,verbose=2)))
print("Model suggested in test set "+str(model_suggested.evaluate(X_test,Y_test,verbose=2)))
print("Model 2 in train set "+str(model_2.evaluate(X_train,Y_train,verbose=2)))
print("Model 2 in test set "+str(model_2.evaluate(X_test,Y_test,verbose=2)))
# Out:
# Model suggested in train set [0.016812935300171375, 0.999]
# Model suggested in test set [0.43014482378959656, 0.8566666674613953]
# Model 2 in train set [0.019597474977374078, 0.996]
# Model 2 in test set [0.11573949029048283, 0.953333334128062]

# %% [markdown]
# # A regression problem.

# %% [markdown]
# In this part, I trained different CNN to detect the vertices of a triangle. As this problem is harder than a classification problem,  I increased the number of samples to 5000.
# I started by doing a normalization of the train set. That is, I reordered the set of vertices according to their x value.
#
# I also tried to order the vertices according to the angles of the triangle. But I was not satisfied with the results.
#
# I got the best results by ordering by the x value.

# %%
def order_corners(Y):
    Y_ordered=Y_train
    for i in range(Y.shape[0]):
        first_point=np.argsort([Y[i][0],Y[i][2],Y[i][4]])
        Y_ordered[i][[0,2,4]]=Y_train[i][[0,2,4]][first_point]
        Y_ordered[i][[1,3,5]]=Y_train[i][[1,3,5]][first_point]
    return(Y_ordered)

# %%
[X_train, Y_train] = generate_dataset_regression(5000, 20,verbose=False)
# Out:
# Creating data:

# %%
X_train=X_train.reshape(X_train.shape[0],72,72,1)

# %%
Y_train_ordered=order_corners(Y_train)

# %% [markdown]
# The first model I analyzed was the suggested one. The results are far away of being optimal. The problem requiere us to learn features that depend on the position and orientation of the triangle and just using a convolutional network is enable to do that.

# %%
mcp = ModelCheckpoint('suggested_reg_model.hdf5', monitor="val_loss",
                      save_best_only=True, save_weights_only=False)
model_suggested_reg=Sequential()
model_suggested_reg.add(Conv2D(16,(5,5),activation="relu",input_shape=(72,72,1)))
model_suggested_reg.add(MaxPooling2D(pool_size=(3,3)))
model_suggested_reg.add(Flatten())
model_suggested_reg.add(Dense(6))
model_suggested_reg.compile(loss="mean_squared_error",
              optimizer="adam")
model_suggested_reg.fit(X_train,Y_train_ordered,
          batch_size=32,validation_split=0.1,epochs=300,verbose=2,callbacks=[mcp])
# Out:
# Train on 4500 samples, validate on 500 samples
# Epoch 1/300
#  - 1s - loss: 0.0468 - val_loss: 0.0253
# Epoch 2/300
#  - 1s - loss: 0.0237 - val_loss: 0.0221
# Epoch 3/300
#  - 1s - loss: 0.0204 - val_loss: 0.0207
# Epoch 4/300
#  - 1s - loss: 0.0183 - val_loss: 0.0183
# Epoch 5/300
#  - 1s - loss: 0.0165 - val_loss: 0.0179
# Epoch 6/300
#  - 1s - loss: 0.0155 - val_loss: 0.0170
# Epoch 7/300
#  - 1s - loss: 0.0148 - val_loss: 0.0165
# Epoch 8/300
#  - 1s - loss: 0.0142 - val_loss: 0.0158
# Epoch 9/300
#  - 1s - loss: 0.0135 - val_loss: 0.0157
# Epoch 10/300
#  - 1s - loss: 0.0130 - val_loss: 0.0155
# Epoch 11/300
#  - 1s - loss: 0.0126 - val_loss: 0.0151
# Epoch 12/300
#  - 1s - loss: 0.0124 - val_loss: 0.0145
# Epoch 13/300
#  - 1s - loss: 0.0118 - val_loss: 0.0153
# Epoch 14/300
#  - 1s - loss: 0.0115 - val_loss: 0.0157
# Epoch 15/300
#  - 1s - loss: 0.0113 - val_loss: 0.0151
# Epoch 16/300
#  - 1s - loss: 0.0109 - val_loss: 0.0152
# Epoch 17/300
#  - 1s - loss: 0.0106 - val_loss: 0.0144
# Epoch 18/300
#  - 1s - loss: 0.0103 - val_loss: 0.0146
# Epoch 19/300
#  - 1s - loss: 0.0102 - val_loss: 0.0137
# Epoch 20/300
#  - 1s - loss: 0.0098 - val_loss: 0.0139
# Epoch 21/300
#  - 1s - loss: 0.0103 - val_loss: 0.0137
# Epoch 22/300
#  - 1s - loss: 0.0097 - val_loss: 0.0138
# Epoch 23/300
#  - 1s - loss: 0.0092 - val_loss: 0.0138
# Epoch 24/300
#  - 1s - loss: 0.0092 - val_loss: 0.0138
# Epoch 25/300
#  - 1s - loss: 0.0090 - val_loss: 0.0138
# Epoch 26/300
#  - 1s - loss: 0.0089 - val_loss: 0.0161
# Epoch 27/300
#  - 1s - loss: 0.0088 - val_loss: 0.0134
# Epoch 28/300
#  - 1s - loss: 0.0086 - val_loss: 0.0141
# Epoch 29/300
#  - 1s - loss: 0.0086 - val_loss: 0.0134
# Epoch 30/300
#  - 1s - loss: 0.0084 - val_loss: 0.0134
# Epoch 31/300
#  - 1s - loss: 0.0083 - val_loss: 0.0136
# Epoch 32/300
#  - 1s - loss: 0.0079 - val_loss: 0.0139
# Epoch 33/300
#  - 1s - loss: 0.0077 - val_loss: 0.0135
# Epoch 34/300
#  - 1s - loss: 0.0079 - val_loss: 0.0140
# Epoch 35/300
#  - 1s - loss: 0.0078 - val_loss: 0.0139
# Epoch 36/300
#  - 1s - loss: 0.0074 - val_loss: 0.0141
# Epoch 37/300
#  - 1s - loss: 0.0075 - val_loss: 0.0148
# Epoch 38/300
#  - 1s - loss: 0.0072 - val_loss: 0.0141
# Epoch 39/300
#  - 1s - loss: 0.0070 - val_loss: 0.0140
# Epoch 40/300
#  - 1s - loss: 0.0072 - val_loss: 0.0140
# Epoch 41/300
#  - 1s - loss: 0.0069 - val_loss: 0.0137
# Epoch 42/300
#  - 1s - loss: 0.0068 - val_loss: 0.0158
# Epoch 43/300
#  - 1s - loss: 0.0072 - val_loss: 0.0143
# Epoch 44/300
#  - 1s - loss: 0.0066 - val_loss: 0.0143
# Epoch 45/300
#  - 1s - loss: 0.0064 - val_loss: 0.0141
# Epoch 46/300
#  - 1s - loss: 0.0066 - val_loss: 0.0144
# Epoch 47/300
#  - 1s - loss: 0.0066 - val_loss: 0.0148
# Epoch 48/300
#  - 1s - loss: 0.0066 - val_loss: 0.0142
# Epoch 49/300
#  - 1s - loss: 0.0062 - val_loss: 0.0145
# Epoch 50/300
#  - 1s - loss: 0.0063 - val_loss: 0.0142
# Epoch 51/300
#  - 1s - loss: 0.0061 - val_loss: 0.0146
# Epoch 52/300
#  - 1s - loss: 0.0061 - val_loss: 0.0143
# Epoch 53/300
#  - 1s - loss: 0.0058 - val_loss: 0.0156
# Epoch 54/300
#  - 1s - loss: 0.0062 - val_loss: 0.0142
# Epoch 55/300
#  - 1s - loss: 0.0060 - val_loss: 0.0150
# Epoch 56/300
#  - 1s - loss: 0.0056 - val_loss: 0.0150
# Epoch 57/300
#  - 1s - loss: 0.0056 - val_loss: 0.0155
# Epoch 58/300
#  - 1s - loss: 0.0057 - val_loss: 0.0161
# Epoch 59/300
#  - 1s - loss: 0.0057 - val_loss: 0.0152
# Epoch 60/300
#  - 1s - loss: 0.0058 - val_loss: 0.0167
# Epoch 61/300
#  - 1s - loss: 0.0055 - val_loss: 0.0154
# Epoch 62/300
#  - 1s - loss: 0.0054 - val_loss: 0.0161
# Epoch 63/300
#  - 1s - loss: 0.0054 - val_loss: 0.0153
# Epoch 64/300
#  - 1s - loss: 0.0050 - val_loss: 0.0158
# Epoch 65/300
#  - 1s - loss: 0.0052 - val_loss: 0.0153
# Epoch 66/300
#  - 1s - loss: 0.0051 - val_loss: 0.0159
# Epoch 67/300
#  - 1s - loss: 0.0050 - val_loss: 0.0158
# Epoch 68/300
#  - 1s - loss: 0.0052 - val_loss: 0.0155
# Epoch 69/300
#  - 1s - loss: 0.0049 - val_loss: 0.0157
# Epoch 70/300
#  - 1s - loss: 0.0051 - val_loss: 0.0156
# Epoch 71/300
#  - 1s - loss: 0.0049 - val_loss: 0.0170
# Epoch 72/300
#  - 1s - loss: 0.0050 - val_loss: 0.0169
# Epoch 73/300
#  - 1s - loss: 0.0048 - val_loss: 0.0179
# Epoch 74/300
#  - 1s - loss: 0.0048 - val_loss: 0.0169
# Epoch 75/300
#  - 1s - loss: 0.0045 - val_loss: 0.0167
# Epoch 76/300
#  - 1s - loss: 0.0046 - val_loss: 0.0166
# Epoch 77/300
#  - 1s - loss: 0.0045 - val_loss: 0.0166
# Epoch 78/300
#  - 1s - loss: 0.0044 - val_loss: 0.0167
# Epoch 79/300
#  - 1s - loss: 0.0044 - val_loss: 0.0167
# Epoch 80/300
#  - 1s - loss: 0.0045 - val_loss: 0.0174
# Epoch 81/300
#  - 1s - loss: 0.0043 - val_loss: 0.0171
# Epoch 82/300
#  - 1s - loss: 0.0044 - val_loss: 0.0174
# Epoch 83/300
#  - 1s - loss: 0.0043 - val_loss: 0.0179
# Epoch 84/300
#  - 1s - loss: 0.0042 - val_loss: 0.0173
# Epoch 85/300
#  - 1s - loss: 0.0042 - val_loss: 0.0170
# Epoch 86/300
#  - 1s - loss: 0.0039 - val_loss: 0.0175
# Epoch 87/300
#  - 1s - loss: 0.0040 - val_loss: 0.0173
# Epoch 88/300
#  - 1s - loss: 0.0039 - val_loss: 0.0178
# Epoch 89/300
#  - 1s - loss: 0.0039 - val_loss: 0.0187
# Epoch 90/300
#  - 1s - loss: 0.0038 - val_loss: 0.0177
# Epoch 91/300
#  - 1s - loss: 0.0037 - val_loss: 0.0178
# Epoch 92/300
#  - 1s - loss: 0.0038 - val_loss: 0.0185
# Epoch 93/300
#  - 1s - loss: 0.0038 - val_loss: 0.0182
# Epoch 94/300
#  - 1s - loss: 0.0036 - val_loss: 0.0182
# Epoch 95/300
#  - 1s - loss: 0.0035 - val_loss: 0.0180
# Epoch 96/300
#  - 1s - loss: 0.0036 - val_loss: 0.0185
# Epoch 97/300
#  - 1s - loss: 0.0036 - val_loss: 0.0192
# Epoch 98/300
#  - 1s - loss: 0.0036 - val_loss: 0.0185
# Epoch 99/300
#  - 1s - loss: 0.0035 - val_loss: 0.0185
# Epoch 100/300
#  - 1s - loss: 0.0035 - val_loss: 0.0195
# Epoch 101/300
#  - 1s - loss: 0.0036 - val_loss: 0.0193
# Epoch 102/300
#  - 1s - loss: 0.0034 - val_loss: 0.0184
# Epoch 103/300
#  - 1s - loss: 0.0035 - val_loss: 0.0191
# Epoch 104/300
#  - 1s - loss: 0.0035 - val_loss: 0.0190
# Epoch 105/300
#  - 1s - loss: 0.0034 - val_loss: 0.0198
# Epoch 106/300
#  - 1s - loss: 0.0035 - val_loss: 0.0193
# Epoch 107/300
#  - 1s - loss: 0.0032 - val_loss: 0.0191
# Epoch 108/300
#  - 1s - loss: 0.0031 - val_loss: 0.0193
# Epoch 109/300
#  - 1s - loss: 0.0033 - val_loss: 0.0189
# Epoch 110/300
#  - 1s - loss: 0.0032 - val_loss: 0.0194
# Epoch 111/300
#  - 1s - loss: 0.0031 - val_loss: 0.0201
# Epoch 112/300
#  - 1s - loss: 0.0031 - val_loss: 0.0202
# Epoch 113/300
#  - 1s - loss: 0.0032 - val_loss: 0.0201
# Epoch 114/300
#  - 1s - loss: 0.0030 - val_loss: 0.0202
# Epoch 115/300
#  - 1s - loss: 0.0030 - val_loss: 0.0201
# Epoch 116/300
#  - 1s - loss: 0.0031 - val_loss: 0.0201
# Epoch 117/300
#  - 1s - loss: 0.0030 - val_loss: 0.0203
# Epoch 118/300
#  - 1s - loss: 0.0030 - val_loss: 0.0205
# Epoch 119/300
#  - 1s - loss: 0.0032 - val_loss: 0.0208
# Epoch 120/300
#  - 1s - loss: 0.0028 - val_loss: 0.0207
# Epoch 121/300
#  - 1s - loss: 0.0031 - val_loss: 0.0214
# Epoch 122/300
#  - 1s - loss: 0.0030 - val_loss: 0.0214
# Epoch 123/300
#  - 1s - loss: 0.0029 - val_loss: 0.0214
# Epoch 124/300
#  - 1s - loss: 0.0027 - val_loss: 0.0209
# Epoch 125/300
#  - 1s - loss: 0.0028 - val_loss: 0.0211
# Epoch 126/300
#  - 1s - loss: 0.0028 - val_loss: 0.0212
# Epoch 127/300
#  - 1s - loss: 0.0027 - val_loss: 0.0211
# Epoch 128/300
#  - 1s - loss: 0.0027 - val_loss: 0.0212
# Epoch 129/300
#  - 1s - loss: 0.0025 - val_loss: 0.0219
# Epoch 130/300
#  - 1s - loss: 0.0028 - val_loss: 0.0215
# Epoch 131/300
#  - 1s - loss: 0.0026 - val_loss: 0.0219
# Epoch 132/300
#  - 1s - loss: 0.0026 - val_loss: 0.0218
# Epoch 133/300
#  - 1s - loss: 0.0028 - val_loss: 0.0220
# Epoch 134/300
#  - 1s - loss: 0.0027 - val_loss: 0.0221
# Epoch 135/300
#  - 1s - loss: 0.0026 - val_loss: 0.0213
# Epoch 136/300
#  - 1s - loss: 0.0027 - val_loss: 0.0219
# Epoch 137/300
#  - 1s - loss: 0.0028 - val_loss: 0.0219
# Epoch 138/300
#  - 1s - loss: 0.0026 - val_loss: 0.0226
# Epoch 139/300
#  - 1s - loss: 0.0025 - val_loss: 0.0222
# Epoch 140/300
#  - 1s - loss: 0.0025 - val_loss: 0.0224
# Epoch 141/300
#  - 1s - loss: 0.0024 - val_loss: 0.0219
# Epoch 142/300
#  - 1s - loss: 0.0024 - val_loss: 0.0226
# Epoch 143/300
#  - 1s - loss: 0.0025 - val_loss: 0.0229
# Epoch 144/300
#  - 1s - loss: 0.0025 - val_loss: 0.0226
# Epoch 145/300
#  - 1s - loss: 0.0023 - val_loss: 0.0227
# Epoch 146/300
#  - 1s - loss: 0.0026 - val_loss: 0.0233
# Epoch 147/300
#  - 1s - loss: 0.0025 - val_loss: 0.0232
# Epoch 148/300
#  - 1s - loss: 0.0024 - val_loss: 0.0228
# Epoch 149/300
#  - 1s - loss: 0.0024 - val_loss: 0.0233
# Epoch 150/300
#  - 1s - loss: 0.0023 - val_loss: 0.0230
# Epoch 151/300
#  - 1s - loss: 0.0023 - val_loss: 0.0230
# Epoch 152/300
#  - 1s - loss: 0.0023 - val_loss: 0.0233
# Epoch 153/300
#  - 1s - loss: 0.0022 - val_loss: 0.0244
# Epoch 154/300
#  - 1s - loss: 0.0024 - val_loss: 0.0242
# Epoch 155/300
#  - 1s - loss: 0.0024 - val_loss: 0.0239
# Epoch 156/300
#  - 1s - loss: 0.0022 - val_loss: 0.0241
# Epoch 157/300
#  - 1s - loss: 0.0024 - val_loss: 0.0242
# Epoch 158/300
#  - 1s - loss: 0.0023 - val_loss: 0.0240
# Epoch 159/300
#  - 1s - loss: 0.0023 - val_loss: 0.0242
# Epoch 160/300
#  - 1s - loss: 0.0021 - val_loss: 0.0249
# Epoch 161/300
#  - 1s - loss: 0.0022 - val_loss: 0.0245
# Epoch 162/300
#  - 1s - loss: 0.0021 - val_loss: 0.0246
# Epoch 163/300
#  - 1s - loss: 0.0021 - val_loss: 0.0247
# Epoch 164/300
#  - 1s - loss: 0.0023 - val_loss: 0.0249
# Epoch 165/300
#  - 1s - loss: 0.0022 - val_loss: 0.0246
# Epoch 166/300
#  - 1s - loss: 0.0020 - val_loss: 0.0245
# Epoch 167/300
#  - 1s - loss: 0.0020 - val_loss: 0.0251
# Epoch 168/300
#  - 1s - loss: 0.0020 - val_loss: 0.0253
# Epoch 169/300
#  - 1s - loss: 0.0021 - val_loss: 0.0256
# Epoch 170/300
#  - 1s - loss: 0.0021 - val_loss: 0.0251
# Epoch 171/300
#  - 1s - loss: 0.0020 - val_loss: 0.0258
# Epoch 172/300
#  - 1s - loss: 0.0019 - val_loss: 0.0253
# Epoch 173/300
#  - 1s - loss: 0.0020 - val_loss: 0.0255
# Epoch 174/300
#  - 1s - loss: 0.0021 - val_loss: 0.0255
# Epoch 175/300
#  - 1s - loss: 0.0020 - val_loss: 0.0260
# Epoch 176/300
#  - 1s - loss: 0.0020 - val_loss: 0.0257
# Epoch 177/300
#  - 1s - loss: 0.0019 - val_loss: 0.0257
# Epoch 178/300
#  - 1s - loss: 0.0019 - val_loss: 0.0260
# Epoch 179/300
#  - 1s - loss: 0.0020 - val_loss: 0.0260
# Epoch 180/300
#  - 1s - loss: 0.0019 - val_loss: 0.0261
# Epoch 181/300
#  - 1s - loss: 0.0020 - val_loss: 0.0265
# Epoch 182/300
#  - 1s - loss: 0.0021 - val_loss: 0.0260
# Epoch 183/300
#  - 1s - loss: 0.0019 - val_loss: 0.0271
# Epoch 184/300
#  - 1s - loss: 0.0018 - val_loss: 0.0270
# Epoch 185/300
#  - 1s - loss: 0.0019 - val_loss: 0.0261
# Epoch 186/300
#  - 1s - loss: 0.0019 - val_loss: 0.0270
# Epoch 187/300
#  - 1s - loss: 0.0018 - val_loss: 0.0269
# Epoch 188/300
#  - 1s - loss: 0.0017 - val_loss: 0.0271
# Epoch 189/300
#  - 1s - loss: 0.0019 - val_loss: 0.0267
# Epoch 190/300
#  - 1s - loss: 0.0020 - val_loss: 0.0280
# Epoch 191/300
#  - 1s - loss: 0.0019 - val_loss: 0.0270
# Epoch 192/300
#  - 1s - loss: 0.0019 - val_loss: 0.0271
# Epoch 193/300
#  - 1s - loss: 0.0018 - val_loss: 0.0270
# Epoch 194/300
#  - 1s - loss: 0.0018 - val_loss: 0.0272
# Epoch 195/300
#  - 1s - loss: 0.0017 - val_loss: 0.0270
# Epoch 196/300
#  - 1s - loss: 0.0017 - val_loss: 0.0272
# Epoch 197/300
#  - 1s - loss: 0.0017 - val_loss: 0.0280
# Epoch 198/300
#  - 1s - loss: 0.0018 - val_loss: 0.0277
# Epoch 199/300
#  - 1s - loss: 0.0018 - val_loss: 0.0273
# Epoch 200/300
#  - 1s - loss: 0.0018 - val_loss: 0.0280
# Epoch 201/300
#  - 1s - loss: 0.0016 - val_loss: 0.0280
# Epoch 202/300
#  - 1s - loss: 0.0016 - val_loss: 0.0278
# Epoch 203/300
#  - 1s - loss: 0.0015 - val_loss: 0.0281
# Epoch 204/300
#  - 1s - loss: 0.0018 - val_loss: 0.0284
# Epoch 205/300
#  - 1s - loss: 0.0018 - val_loss: 0.0284
# Epoch 206/300
#  - 1s - loss: 0.0017 - val_loss: 0.0286
# Epoch 207/300
#  - 1s - loss: 0.0017 - val_loss: 0.0279
# Epoch 208/300
#  - 1s - loss: 0.0016 - val_loss: 0.0284
# Epoch 209/300
#  - 1s - loss: 0.0017 - val_loss: 0.0292
# Epoch 210/300
#  - 1s - loss: 0.0016 - val_loss: 0.0288
# Epoch 211/300
#  - 1s - loss: 0.0016 - val_loss: 0.0294
# Epoch 212/300
#  - 1s - loss: 0.0015 - val_loss: 0.0291
# Epoch 213/300
#  - 1s - loss: 0.0016 - val_loss: 0.0294
# Epoch 214/300
#  - 1s - loss: 0.0015 - val_loss: 0.0290
# Epoch 215/300
#  - 1s - loss: 0.0015 - val_loss: 0.0293
# Epoch 216/300
#  - 1s - loss: 0.0015 - val_loss: 0.0290
# Epoch 217/300
#  - 1s - loss: 0.0014 - val_loss: 0.0302
# Epoch 218/300
#  - 1s - loss: 0.0016 - val_loss: 0.0300
# Epoch 219/300
#  - 1s - loss: 0.0015 - val_loss: 0.0300
# Epoch 220/300
#  - 1s - loss: 0.0015 - val_loss: 0.0297
# Epoch 221/300
#  - 1s - loss: 0.0016 - val_loss: 0.0298
# Epoch 222/300
#  - 1s - loss: 0.0016 - val_loss: 0.0294
# Epoch 223/300
#  - 1s - loss: 0.0014 - val_loss: 0.0300
# Epoch 224/300
#  - 1s - loss: 0.0016 - val_loss: 0.0298
# Epoch 225/300
#  - 1s - loss: 0.0015 - val_loss: 0.0303
# Epoch 226/300
#  - 1s - loss: 0.0015 - val_loss: 0.0305
# Epoch 227/300
#  - 1s - loss: 0.0014 - val_loss: 0.0307
# Epoch 228/300
#  - 1s - loss: 0.0015 - val_loss: 0.0302
# Epoch 229/300
#  - 1s - loss: 0.0015 - val_loss: 0.0301
# Epoch 230/300
#  - 1s - loss: 0.0014 - val_loss: 0.0307
# Epoch 231/300
#  - 1s - loss: 0.0015 - val_loss: 0.0307
# Epoch 232/300
#  - 1s - loss: 0.0014 - val_loss: 0.0308
# Epoch 233/300
#  - 1s - loss: 0.0013 - val_loss: 0.0308
# Epoch 234/300
#  - 1s - loss: 0.0014 - val_loss: 0.0313
# Epoch 235/300
#  - 1s - loss: 0.0016 - val_loss: 0.0314
# Epoch 236/300
#  - 1s - loss: 0.0014 - val_loss: 0.0306
# Epoch 237/300
#  - 1s - loss: 0.0012 - val_loss: 0.0310
# Epoch 238/300
#  - 1s - loss: 0.0013 - val_loss: 0.0312
# Epoch 239/300
#  - 1s - loss: 0.0013 - val_loss: 0.0315
# Epoch 240/300
#  - 1s - loss: 0.0012 - val_loss: 0.0317
# Epoch 241/300
#  - 1s - loss: 0.0013 - val_loss: 0.0314
# Epoch 242/300
#  - 1s - loss: 0.0012 - val_loss: 0.0319
# Epoch 243/300
#  - 1s - loss: 0.0013 - val_loss: 0.0322
# Epoch 244/300
#  - 1s - loss: 0.0014 - val_loss: 0.0319
# Epoch 245/300
#  - 1s - loss: 0.0013 - val_loss: 0.0321
# Epoch 246/300
#  - 1s - loss: 0.0014 - val_loss: 0.0322
# Epoch 247/300
#  - 1s - loss: 0.0014 - val_loss: 0.0321
# Epoch 248/300
#  - 1s - loss: 0.0012 - val_loss: 0.0319
# Epoch 249/300
#  - 1s - loss: 0.0013 - val_loss: 0.0320
# Epoch 250/300
#  - 1s - loss: 0.0012 - val_loss: 0.0324
# Epoch 251/300
#  - 1s - loss: 0.0012 - val_loss: 0.0322
# Epoch 252/300
#  - 1s - loss: 0.0012 - val_loss: 0.0325
# Epoch 253/300
#  - 1s - loss: 0.0012 - val_loss: 0.0324
# Epoch 254/300
#  - 1s - loss: 0.0012 - val_loss: 0.0332
# Epoch 255/300
#  - 1s - loss: 0.0012 - val_loss: 0.0326
# Epoch 256/300
#  - 1s - loss: 0.0013 - val_loss: 0.0329
# Epoch 257/300
#  - 1s - loss: 0.0013 - val_loss: 0.0327
# Epoch 258/300
#  - 1s - loss: 0.0012 - val_loss: 0.0336
# Epoch 259/300
#  - 1s - loss: 0.0012 - val_loss: 0.0332
# Epoch 260/300
#  - 1s - loss: 0.0014 - val_loss: 0.0328
# Epoch 261/300
#  - 1s - loss: 0.0012 - val_loss: 0.0330
# Epoch 262/300
#  - 1s - loss: 0.0011 - val_loss: 0.0328
# Epoch 263/300
#  - 1s - loss: 0.0012 - val_loss: 0.0334
# Epoch 264/300
#  - 1s - loss: 0.0012 - val_loss: 0.0337
# Epoch 265/300
#  - 1s - loss: 0.0013 - val_loss: 0.0340
# Epoch 266/300
#  - 1s - loss: 0.0012 - val_loss: 0.0334
# Epoch 267/300
#  - 1s - loss: 0.0012 - val_loss: 0.0333
# Epoch 268/300
#  - 1s - loss: 0.0011 - val_loss: 0.0341
# Epoch 269/300
#  - 1s - loss: 0.0012 - val_loss: 0.0344
# Epoch 270/300
#  - 1s - loss: 0.0012 - val_loss: 0.0348
# Epoch 271/300
#  - 1s - loss: 0.0012 - val_loss: 0.0337
# Epoch 272/300
#  - 1s - loss: 0.0012 - val_loss: 0.0345
# Epoch 273/300
#  - 1s - loss: 0.0011 - val_loss: 0.0350
# Epoch 274/300
#  - 1s - loss: 0.0011 - val_loss: 0.0350
# Epoch 275/300
#  - 1s - loss: 0.0012 - val_loss: 0.0343
# Epoch 276/300
#  - 1s - loss: 0.0011 - val_loss: 0.0341
# Epoch 277/300
#  - 1s - loss: 0.0013 - val_loss: 0.0352
# Epoch 278/300
#  - 1s - loss: 0.0013 - val_loss: 0.0346
# Epoch 279/300
#  - 1s - loss: 0.0011 - val_loss: 0.0348
# Epoch 280/300
#  - 1s - loss: 0.0011 - val_loss: 0.0351
# Epoch 281/300
#  - 1s - loss: 0.0011 - val_loss: 0.0349
# Epoch 282/300
#  - 1s - loss: 0.0010 - val_loss: 0.0348
# Epoch 283/300
#  - 1s - loss: 0.0010 - val_loss: 0.0357
# Epoch 284/300
#  - 1s - loss: 0.0011 - val_loss: 0.0351
# Epoch 285/300
#  - 1s - loss: 0.0010 - val_loss: 0.0357
# Epoch 286/300
#  - 1s - loss: 9.9673e-04 - val_loss: 0.0355
# Epoch 287/300
#  - 1s - loss: 0.0010 - val_loss: 0.0351
# Epoch 288/300
#  - 1s - loss: 0.0010 - val_loss: 0.0353
# Epoch 289/300
#  - 1s - loss: 0.0012 - val_loss: 0.0356
# Epoch 290/300
#  - 1s - loss: 0.0012 - val_loss: 0.0360
# Epoch 291/300
#  - 1s - loss: 0.0011 - val_loss: 0.0355
# Epoch 292/300
#  - 1s - loss: 9.6660e-04 - val_loss: 0.0359
# Epoch 293/300
#  - 1s - loss: 9.0472e-04 - val_loss: 0.0351
# Epoch 294/300
#  - 1s - loss: 9.4038e-04 - val_loss: 0.0361
# Epoch 295/300
#  - 1s - loss: 0.0011 - val_loss: 0.0357
# Epoch 296/300
#  - 1s - loss: 0.0010 - val_loss: 0.0362
# Epoch 297/300
#  - 1s - loss: 9.6648e-04 - val_loss: 0.0367
# Epoch 298/300
#  - 1s - loss: 0.0011 - val_loss: 0.0360
# Epoch 299/300
#  - 1s - loss: 0.0011 - val_loss: 0.0370
# Epoch 300/300
#  - 1s - loss: 0.0010 - val_loss: 0.0369

# %%
[X_test, Y_test] = generate_test_set_regression(verbose=False)
X_test=X_test.reshape(X_test.shape[0],72,72,1)
Y_test_ordered=order_corners(Y_test)
# Out:
# Creating data:

# %%
Y_predict_1=model_suggested_reg.predict(X_test)

# %%
for i in range(10):
    visualize_prediction(X_test[i], Y_predict_1[i])

# %% [markdown]
# For the secon model,I increased the number of convulutional layers, a dense layer and I added dropout to avoid overfitting. The results are better, but they can be improved.

# %%
model_2_reg=Sequential()
model_2_reg.add(Conv2D(32,(5,5),activation="relu",input_shape=(72,72,1)))
model_2_reg.add(MaxPooling2D(pool_size=(2,2)))
model_2_reg.add(Dropout(0.5))
model_2_reg.add(Conv2D(32,(5,5),activation="relu",input_shape=(72,72,1)))
model_2_reg.add(MaxPooling2D(pool_size=(2,2)))
model_2_reg.add(Dropout(0.25))
model_2_reg.add(Conv2D(32,(5,5),activation="relu",input_shape=(72,72,1)))
model_2_reg.add(MaxPooling2D(pool_size=(2,2)))
model_2_reg.add(Flatten())
model_2_reg.add(Dropout(0.25))
model_2_reg.add(Dense(64,activation="relu"))
model_2_reg.add(Dense(6))
adam = optimizers.adam(lr=1e-4)
model_2_reg.compile(loss="mean_squared_error",optimizer=adam)
model_2_reg.fit(X_train,Y_train_ordered,
          batch_size=32,validation_split=0.1,epochs=250,verbose=2)
# Out:
# Train on 4500 samples, validate on 500 samples
# Epoch 1/250
#  - 3s - loss: 0.0851 - val_loss: 0.2369
# Epoch 2/250
#  - 2s - loss: 0.0617 - val_loss: 0.1832
# Epoch 3/250
#  - 2s - loss: 0.0504 - val_loss: 0.1612
# Epoch 4/250
#  - 2s - loss: 0.0454 - val_loss: 0.1380
# Epoch 5/250
#  - 2s - loss: 0.0420 - val_loss: 0.1148
# Epoch 6/250
#  - 2s - loss: 0.0394 - val_loss: 0.1085
# Epoch 7/250
#  - 2s - loss: 0.0370 - val_loss: 0.0914
# Epoch 8/250
#  - 2s - loss: 0.0349 - val_loss: 0.0835
# Epoch 9/250
#  - 2s - loss: 0.0329 - val_loss: 0.0790
# Epoch 10/250
#  - 2s - loss: 0.0317 - val_loss: 0.0734
# Epoch 11/250
#  - 2s - loss: 0.0302 - val_loss: 0.0698
# Epoch 12/250
#  - 2s - loss: 0.0290 - val_loss: 0.0647
# Epoch 13/250
#  - 2s - loss: 0.0280 - val_loss: 0.0567
# Epoch 14/250
#  - 2s - loss: 0.0273 - val_loss: 0.0582
# Epoch 15/250
#  - 2s - loss: 0.0262 - val_loss: 0.0517
# Epoch 16/250
#  - 2s - loss: 0.0254 - val_loss: 0.0489
# Epoch 17/250
#  - 2s - loss: 0.0245 - val_loss: 0.0470
# Epoch 18/250
#  - 2s - loss: 0.0238 - val_loss: 0.0452
# Epoch 19/250
#  - 2s - loss: 0.0231 - val_loss: 0.0424
# Epoch 20/250
#  - 2s - loss: 0.0225 - val_loss: 0.0388
# Epoch 21/250
#  - 2s - loss: 0.0217 - val_loss: 0.0377
# Epoch 22/250
#  - 2s - loss: 0.0215 - val_loss: 0.0355
# Epoch 23/250
#  - 2s - loss: 0.0208 - val_loss: 0.0327
# Epoch 24/250
#  - 2s - loss: 0.0203 - val_loss: 0.0320
# Epoch 25/250
#  - 2s - loss: 0.0202 - val_loss: 0.0279
# Epoch 26/250
#  - 2s - loss: 0.0194 - val_loss: 0.0301
# Epoch 27/250
#  - 2s - loss: 0.0193 - val_loss: 0.0276
# Epoch 28/250
#  - 2s - loss: 0.0188 - val_loss: 0.0274
# Epoch 29/250
#  - 2s - loss: 0.0186 - val_loss: 0.0242
# Epoch 30/250
#  - 2s - loss: 0.0185 - val_loss: 0.0243
# Epoch 31/250
#  - 2s - loss: 0.0178 - val_loss: 0.0209
# Epoch 32/250
#  - 2s - loss: 0.0176 - val_loss: 0.0228
# Epoch 33/250
#  - 2s - loss: 0.0173 - val_loss: 0.0209
# Epoch 34/250
#  - 2s - loss: 0.0170 - val_loss: 0.0204
# Epoch 35/250
#  - 2s - loss: 0.0168 - val_loss: 0.0211
# Epoch 36/250
#  - 2s - loss: 0.0168 - val_loss: 0.0180
# Epoch 37/250
#  - 2s - loss: 0.0165 - val_loss: 0.0200
# Epoch 38/250
#  - 2s - loss: 0.0162 - val_loss: 0.0184
# Epoch 39/250
#  - 2s - loss: 0.0161 - val_loss: 0.0208
# Epoch 40/250
#  - 2s - loss: 0.0157 - val_loss: 0.0179
# Epoch 41/250
#  - 2s - loss: 0.0156 - val_loss: 0.0183
# Epoch 42/250
#  - 2s - loss: 0.0156 - val_loss: 0.0190
# Epoch 43/250
#  - 2s - loss: 0.0154 - val_loss: 0.0181
# Epoch 44/250
#  - 2s - loss: 0.0152 - val_loss: 0.0159
# Epoch 45/250
#  - 2s - loss: 0.0151 - val_loss: 0.0170
# Epoch 46/250
#  - 2s - loss: 0.0151 - val_loss: 0.0167
# Epoch 47/250
#  - 2s - loss: 0.0148 - val_loss: 0.0149
# Epoch 48/250
#  - 2s - loss: 0.0148 - val_loss: 0.0152
# Epoch 49/250
#  - 2s - loss: 0.0145 - val_loss: 0.0145
# Epoch 50/250
#  - 2s - loss: 0.0144 - val_loss: 0.0154
# Epoch 51/250
#  - 2s - loss: 0.0143 - val_loss: 0.0140
# Epoch 52/250
#  - 2s - loss: 0.0143 - val_loss: 0.0147
# Epoch 53/250
#  - 2s - loss: 0.0142 - val_loss: 0.0142
# Epoch 54/250
#  - 2s - loss: 0.0139 - val_loss: 0.0123
# Epoch 55/250
#  - 2s - loss: 0.0138 - val_loss: 0.0146
# Epoch 56/250
#  - 2s - loss: 0.0138 - val_loss: 0.0143
# Epoch 57/250
#  - 2s - loss: 0.0138 - val_loss: 0.0131
# Epoch 58/250
#  - 2s - loss: 0.0136 - val_loss: 0.0139
# Epoch 59/250
#  - 2s - loss: 0.0135 - val_loss: 0.0134
# Epoch 60/250
#  - 2s - loss: 0.0134 - val_loss: 0.0131
# Epoch 61/250
#  - 2s - loss: 0.0133 - val_loss: 0.0125
# Epoch 62/250
#  - 2s - loss: 0.0132 - val_loss: 0.0128
# Epoch 63/250
#  - 2s - loss: 0.0133 - val_loss: 0.0128
# Epoch 64/250
#  - 2s - loss: 0.0132 - val_loss: 0.0126
# Epoch 65/250
#  - 2s - loss: 0.0131 - val_loss: 0.0121
# Epoch 66/250
#  - 2s - loss: 0.0130 - val_loss: 0.0126
# Epoch 67/250
#  - 2s - loss: 0.0130 - val_loss: 0.0126
# Epoch 68/250
#  - 2s - loss: 0.0130 - val_loss: 0.0112
# Epoch 69/250
#  - 2s - loss: 0.0126 - val_loss: 0.0115
# Epoch 70/250
#  - 2s - loss: 0.0127 - val_loss: 0.0114
# Epoch 71/250
#  - 2s - loss: 0.0126 - val_loss: 0.0126
# Epoch 72/250
#  - 2s - loss: 0.0124 - val_loss: 0.0120
# Epoch 73/250
#  - 2s - loss: 0.0123 - val_loss: 0.0117
# Epoch 74/250
#  - 2s - loss: 0.0123 - val_loss: 0.0109
# Epoch 75/250
#  - 2s - loss: 0.0123 - val_loss: 0.0113
# Epoch 76/250
#  - 2s - loss: 0.0123 - val_loss: 0.0104
# Epoch 77/250
#  - 2s - loss: 0.0121 - val_loss: 0.0105
# Epoch 78/250
#  - 2s - loss: 0.0121 - val_loss: 0.0090
# Epoch 79/250
#  - 2s - loss: 0.0123 - val_loss: 0.0101
# Epoch 80/250
#  - 2s - loss: 0.0120 - val_loss: 0.0106
# Epoch 81/250
#  - 2s - loss: 0.0122 - val_loss: 0.0109
# Epoch 82/250
#  - 2s - loss: 0.0120 - val_loss: 0.0107
# Epoch 83/250
#  - 2s - loss: 0.0120 - val_loss: 0.0103
# Epoch 84/250
#  - 2s - loss: 0.0119 - val_loss: 0.0113
# Epoch 85/250
#  - 2s - loss: 0.0118 - val_loss: 0.0106
# Epoch 86/250
#  - 2s - loss: 0.0119 - val_loss: 0.0107
# Epoch 87/250
#  - 2s - loss: 0.0117 - val_loss: 0.0097
# Epoch 88/250
#  - 2s - loss: 0.0116 - val_loss: 0.0108
# Epoch 89/250
#  - 2s - loss: 0.0116 - val_loss: 0.0092
# Epoch 90/250
#  - 2s - loss: 0.0116 - val_loss: 0.0105
# Epoch 91/250
#  - 2s - loss: 0.0115 - val_loss: 0.0105
# Epoch 92/250
#  - 2s - loss: 0.0112 - val_loss: 0.0088
# Epoch 93/250
#  - 2s - loss: 0.0114 - val_loss: 0.0089
# Epoch 94/250
#  - 2s - loss: 0.0113 - val_loss: 0.0090
# Epoch 95/250
#  - 2s - loss: 0.0114 - val_loss: 0.0098
# Epoch 96/250
#  - 2s - loss: 0.0112 - val_loss: 0.0096
# Epoch 97/250
#  - 2s - loss: 0.0112 - val_loss: 0.0097
# Epoch 98/250
#  - 2s - loss: 0.0112 - val_loss: 0.0093
# Epoch 99/250
#  - 2s - loss: 0.0114 - val_loss: 0.0097
# Epoch 100/250
#  - 2s - loss: 0.0111 - val_loss: 0.0089
# Epoch 101/250
#  - 2s - loss: 0.0111 - val_loss: 0.0098
# Epoch 102/250
#  - 2s - loss: 0.0111 - val_loss: 0.0090
# Epoch 103/250
#  - 2s - loss: 0.0109 - val_loss: 0.0085
# Epoch 104/250
#  - 2s - loss: 0.0108 - val_loss: 0.0096
# Epoch 105/250
#  - 2s - loss: 0.0109 - val_loss: 0.0088
# Epoch 106/250
#  - 2s - loss: 0.0108 - val_loss: 0.0082
# Epoch 107/250
#  - 2s - loss: 0.0108 - val_loss: 0.0082
# Epoch 108/250
#  - 2s - loss: 0.0109 - val_loss: 0.0083
# Epoch 109/250
#  - 2s - loss: 0.0108 - val_loss: 0.0077
# Epoch 110/250
#  - 2s - loss: 0.0108 - val_loss: 0.0085
# Epoch 111/250
#  - 2s - loss: 0.0107 - val_loss: 0.0078
# Epoch 112/250
#  - 2s - loss: 0.0109 - val_loss: 0.0075
# Epoch 113/250
#  - 2s - loss: 0.0107 - val_loss: 0.0084
# Epoch 114/250
#  - 2s - loss: 0.0106 - val_loss: 0.0090
# Epoch 115/250
#  - 2s - loss: 0.0108 - val_loss: 0.0085
# Epoch 116/250
#  - 2s - loss: 0.0105 - val_loss: 0.0076
# Epoch 117/250
#  - 2s - loss: 0.0106 - val_loss: 0.0080
# Epoch 118/250
#  - 2s - loss: 0.0105 - val_loss: 0.0077
# Epoch 119/250
#  - 2s - loss: 0.0106 - val_loss: 0.0077
# Epoch 120/250
#  - 2s - loss: 0.0106 - val_loss: 0.0073
# Epoch 121/250
#  - 2s - loss: 0.0105 - val_loss: 0.0077
# Epoch 122/250
#  - 2s - loss: 0.0103 - val_loss: 0.0082
# Epoch 123/250
#  - 2s - loss: 0.0103 - val_loss: 0.0071
# Epoch 124/250
#  - 2s - loss: 0.0103 - val_loss: 0.0075
# Epoch 125/250
#  - 2s - loss: 0.0102 - val_loss: 0.0071
# Epoch 126/250
#  - 2s - loss: 0.0103 - val_loss: 0.0073
# Epoch 127/250
#  - 2s - loss: 0.0102 - val_loss: 0.0078
# Epoch 128/250
#  - 2s - loss: 0.0102 - val_loss: 0.0074
# Epoch 129/250
#  - 2s - loss: 0.0101 - val_loss: 0.0073
# Epoch 130/250
#  - 2s - loss: 0.0101 - val_loss: 0.0077
# Epoch 131/250
#  - 2s - loss: 0.0102 - val_loss: 0.0071
# Epoch 132/250
#  - 2s - loss: 0.0102 - val_loss: 0.0067
# Epoch 133/250
#  - 2s - loss: 0.0101 - val_loss: 0.0069
# Epoch 134/250
#  - 2s - loss: 0.0101 - val_loss: 0.0071
# Epoch 135/250
#  - 2s - loss: 0.0100 - val_loss: 0.0066
# Epoch 136/250
#  - 2s - loss: 0.0100 - val_loss: 0.0060
# Epoch 137/250
#  - 2s - loss: 0.0100 - val_loss: 0.0071
# Epoch 138/250
#  - 2s - loss: 0.0100 - val_loss: 0.0069
# Epoch 139/250
#  - 2s - loss: 0.0100 - val_loss: 0.0066
# Epoch 140/250
#  - 2s - loss: 0.0099 - val_loss: 0.0065
# Epoch 141/250
#  - 2s - loss: 0.0099 - val_loss: 0.0065
# Epoch 142/250
#  - 2s - loss: 0.0100 - val_loss: 0.0061
# Epoch 143/250
#  - 2s - loss: 0.0099 - val_loss: 0.0066
# Epoch 144/250
#  - 2s - loss: 0.0099 - val_loss: 0.0068
# Epoch 145/250
#  - 2s - loss: 0.0100 - val_loss: 0.0065
# Epoch 146/250
#  - 2s - loss: 0.0098 - val_loss: 0.0060
# Epoch 147/250
#  - 2s - loss: 0.0098 - val_loss: 0.0060
# Epoch 148/250
#  - 2s - loss: 0.0097 - val_loss: 0.0065
# Epoch 149/250
#  - 2s - loss: 0.0098 - val_loss: 0.0071
# Epoch 150/250
#  - 2s - loss: 0.0098 - val_loss: 0.0061
# Epoch 151/250
#  - 2s - loss: 0.0096 - val_loss: 0.0057
# Epoch 152/250
#  - 2s - loss: 0.0096 - val_loss: 0.0055
# Epoch 153/250
#  - 2s - loss: 0.0097 - val_loss: 0.0070
# Epoch 154/250
#  - 2s - loss: 0.0097 - val_loss: 0.0061
# Epoch 155/250
#  - 2s - loss: 0.0098 - val_loss: 0.0064
# Epoch 156/250
#  - 2s - loss: 0.0096 - val_loss: 0.0054
# Epoch 157/250
#  - 2s - loss: 0.0095 - val_loss: 0.0063
# Epoch 158/250
#  - 2s - loss: 0.0096 - val_loss: 0.0061
# Epoch 159/250
#  - 2s - loss: 0.0095 - val_loss: 0.0059
# Epoch 160/250
#  - 2s - loss: 0.0095 - val_loss: 0.0055
# Epoch 161/250
#  - 2s - loss: 0.0094 - val_loss: 0.0062
# Epoch 162/250
#  - 2s - loss: 0.0096 - val_loss: 0.0057
# Epoch 163/250
#  - 2s - loss: 0.0095 - val_loss: 0.0063
# Epoch 164/250
#  - 2s - loss: 0.0093 - val_loss: 0.0064
# Epoch 165/250
#  - 2s - loss: 0.0094 - val_loss: 0.0054
# Epoch 166/250
#  - 2s - loss: 0.0094 - val_loss: 0.0060
# Epoch 167/250
#  - 2s - loss: 0.0094 - val_loss: 0.0055
# Epoch 168/250
#  - 2s - loss: 0.0094 - val_loss: 0.0059
# Epoch 169/250
#  - 2s - loss: 0.0095 - val_loss: 0.0060
# Epoch 170/250
#  - 2s - loss: 0.0095 - val_loss: 0.0058
# Epoch 171/250
#  - 2s - loss: 0.0093 - val_loss: 0.0057
# Epoch 172/250
#  - 2s - loss: 0.0093 - val_loss: 0.0057
# Epoch 173/250
#  - 2s - loss: 0.0093 - val_loss: 0.0058
# Epoch 174/250
#  - 2s - loss: 0.0093 - val_loss: 0.0059
# Epoch 175/250
#  - 2s - loss: 0.0092 - val_loss: 0.0050
# Epoch 176/250
#  - 2s - loss: 0.0093 - val_loss: 0.0052
# Epoch 177/250
#  - 2s - loss: 0.0092 - val_loss: 0.0050
# Epoch 178/250
#  - 2s - loss: 0.0092 - val_loss: 0.0057
# Epoch 179/250
#  - 2s - loss: 0.0092 - val_loss: 0.0058
# Epoch 180/250
#  - 2s - loss: 0.0090 - val_loss: 0.0059
# Epoch 181/250
#  - 2s - loss: 0.0091 - val_loss: 0.0060
# Epoch 182/250
#  - 2s - loss: 0.0093 - val_loss: 0.0056
# Epoch 183/250
#  - 2s - loss: 0.0092 - val_loss: 0.0050
# Epoch 184/250
#  - 2s - loss: 0.0092 - val_loss: 0.0062
# Epoch 185/250
#  - 2s - loss: 0.0091 - val_loss: 0.0056
# Epoch 186/250
#  - 2s - loss: 0.0090 - val_loss: 0.0053
# Epoch 187/250
#  - 2s - loss: 0.0092 - val_loss: 0.0057
# Epoch 188/250
#  - 2s - loss: 0.0091 - val_loss: 0.0053
# Epoch 189/250
#  - 2s - loss: 0.0091 - val_loss: 0.0049
# Epoch 190/250
#  - 2s - loss: 0.0090 - val_loss: 0.0057
# Epoch 191/250
#  - 2s - loss: 0.0091 - val_loss: 0.0052
# Epoch 192/250
#  - 2s - loss: 0.0089 - val_loss: 0.0053
# Epoch 193/250
#  - 2s - loss: 0.0090 - val_loss: 0.0062
# Epoch 194/250
#  - 2s - loss: 0.0090 - val_loss: 0.0050
# Epoch 195/250
#  - 2s - loss: 0.0089 - val_loss: 0.0054
# Epoch 196/250
#  - 2s - loss: 0.0090 - val_loss: 0.0054
# Epoch 197/250
#  - 2s - loss: 0.0089 - val_loss: 0.0049
# Epoch 198/250
#  - 2s - loss: 0.0087 - val_loss: 0.0050
# Epoch 199/250
#  - 2s - loss: 0.0088 - val_loss: 0.0055
# Epoch 200/250
#  - 2s - loss: 0.0088 - val_loss: 0.0050
# Epoch 201/250
#  - 2s - loss: 0.0088 - val_loss: 0.0057
# Epoch 202/250
#  - 2s - loss: 0.0088 - val_loss: 0.0049
# Epoch 203/250
#  - 2s - loss: 0.0088 - val_loss: 0.0050
# Epoch 204/250
#  - 2s - loss: 0.0087 - val_loss: 0.0048
# Epoch 205/250
#  - 2s - loss: 0.0088 - val_loss: 0.0045
# Epoch 206/250
#  - 2s - loss: 0.0088 - val_loss: 0.0048
# Epoch 207/250
#  - 2s - loss: 0.0087 - val_loss: 0.0058
# Epoch 208/250
#  - 2s - loss: 0.0087 - val_loss: 0.0053
# Epoch 209/250
#  - 2s - loss: 0.0088 - val_loss: 0.0052
# Epoch 210/250
#  - 2s - loss: 0.0086 - val_loss: 0.0045
# Epoch 211/250
#  - 2s - loss: 0.0087 - val_loss: 0.0048
# Epoch 212/250
#  - 2s - loss: 0.0086 - val_loss: 0.0051
# Epoch 213/250
#  - 2s - loss: 0.0085 - val_loss: 0.0049
# Epoch 214/250
#  - 2s - loss: 0.0086 - val_loss: 0.0044
# Epoch 215/250
#  - 2s - loss: 0.0087 - val_loss: 0.0054
# Epoch 216/250
#  - 2s - loss: 0.0086 - val_loss: 0.0046
# Epoch 217/250
#  - 2s - loss: 0.0086 - val_loss: 0.0047
# Epoch 218/250
#  - 2s - loss: 0.0086 - val_loss: 0.0050
# Epoch 219/250
#  - 2s - loss: 0.0085 - val_loss: 0.0046
# Epoch 220/250
#  - 2s - loss: 0.0085 - val_loss: 0.0050
# Epoch 221/250
#  - 2s - loss: 0.0085 - val_loss: 0.0046
# Epoch 222/250
#  - 2s - loss: 0.0084 - val_loss: 0.0046
# Epoch 223/250
#  - 2s - loss: 0.0086 - val_loss: 0.0043
# Epoch 224/250
#  - 2s - loss: 0.0085 - val_loss: 0.0043
# Epoch 225/250
#  - 2s - loss: 0.0085 - val_loss: 0.0054
# Epoch 226/250
#  - 2s - loss: 0.0086 - val_loss: 0.0041
# Epoch 227/250
#  - 2s - loss: 0.0085 - val_loss: 0.0046
# Epoch 228/250
#  - 2s - loss: 0.0085 - val_loss: 0.0044
# Epoch 229/250
#  - 2s - loss: 0.0085 - val_loss: 0.0044
# Epoch 230/250
#  - 2s - loss: 0.0085 - val_loss: 0.0046
# Epoch 231/250
#  - 2s - loss: 0.0085 - val_loss: 0.0057
# Epoch 232/250
#  - 2s - loss: 0.0085 - val_loss: 0.0047
# Epoch 233/250
#  - 2s - loss: 0.0084 - val_loss: 0.0046
# Epoch 234/250
#  - 2s - loss: 0.0084 - val_loss: 0.0052
# Epoch 235/250
#  - 2s - loss: 0.0085 - val_loss: 0.0048
# Epoch 236/250
#  - 2s - loss: 0.0085 - val_loss: 0.0049
# Epoch 237/250
#  - 2s - loss: 0.0084 - val_loss: 0.0049
# Epoch 238/250
#  - 2s - loss: 0.0087 - val_loss: 0.0046
# Epoch 239/250
#  - 2s - loss: 0.0084 - val_loss: 0.0124
# Epoch 240/250
#  - 2s - loss: 0.0085 - val_loss: 0.0046
# Epoch 241/250
#  - 2s - loss: 0.0083 - val_loss: 0.0048
# Epoch 242/250
#  - 2s - loss: 0.0083 - val_loss: 0.0046
# Epoch 243/250
#  - 2s - loss: 0.0083 - val_loss: 0.0045
# Epoch 244/250
#  - 2s - loss: 0.0084 - val_loss: 0.0047
# Epoch 245/250
#  - 2s - loss: 0.0082 - val_loss: 0.0048
# Epoch 246/250
#  - 2s - loss: 0.0081 - val_loss: 0.0041
# Epoch 247/250
#  - 2s - loss: 0.0083 - val_loss: 0.0042
# Epoch 248/250
#  - 2s - loss: 0.0082 - val_loss: 0.0045
# Epoch 249/250
#  - 2s - loss: 0.0082 - val_loss: 0.0043
# Epoch 250/250
#  - 2s - loss: 0.0082 - val_loss: 0.0043

# %%
Y_predict_2=model_2_reg.predict(X_test)

# %%
for i in range(40,50):
    visualize_prediction(X_test[i], Y_predict_2[i])

# %% [markdown]
# # Image denoising

# %% [markdown]
# I generated a train set with 500 samples.

# %%
[X_train,Y_train] = generate_dataset_denoising(500, 20,True,verbose=False)
# Out:
# Creating data:

# %%
X_train=X_train.reshape(X_train.shape[0],72,72,1)
Y_train=Y_train.reshape(Y_train.shape[0],72,72,1)

# %% [markdown]
# I trained different hourglass networks. Here you can see the one that I could train faster and had a good performance. Normally, this kind of architecture is used in image segmentation, but in this case I tried to predict the pixel intensity by doing a regression task. For that reason, I did experiments with both loss functions , "mean_squared_error" and "mean_absolute_error". I preferred the results given by the "mean_squared_error".
#
# In a normal hourglass architecture, batchnormalization is done after convolutional layers in order to guarantee the stability of the network during the training and it reduces overfitting. Nevetheless, in this particular case, it just made the training process slower and it did not improve the results, so I did not include it.
#
# The trained hourglas networks use Pooling and Upsampling of dimension 2x2.

# %%
mcp = ModelCheckpoint('denoising_model_1.hdf5', monitor="val_loss",
                      save_best_only=True, save_weights_only=False)


neural_input=Input((72,72,1))

conv1=Conv2D(10,(5,5),activation="relu",padding="same")(neural_input)
#conv1=BatchNormalization()(conv1)
conv1=Conv2D(10,(5,5),activation="relu",padding="same")(conv1)
#conv1=BatchNormalization()(conv1)
pool1=MaxPooling2D(pool_size=(2,2))(conv1)

conv2=Conv2D(20,(5,5),activation="relu",padding="same")(pool1)
#conv2=BatchNormalization()(conv2)
conv2=Conv2D(20,(5,5),activation="relu",padding="same")(conv2)
#conv2=BatchNormalization()(conv2)
pool2=MaxPooling2D(pool_size=(2,2))(conv2)

conv3=Conv2D(40,(5,5),activation="relu",padding="same")(pool2)
#conv3=BatchNormalization()(conv3)
conv3=Conv2D(40,(5,5),activation="relu",padding="same")(conv3)
#conv3=BatchNormalization()(conv3)

up4=UpSampling2D(size=(2,2))(conv3)

up_conv4=Conv2D(20,(5,5),activation="relu",padding="same")(up4)
#up_conv4=BatchNormalization()(up_conv4)
merge4 = concatenate([conv2,up_conv4],axis=3)
conv4=Conv2D(20,(5,5),activation="relu",padding="same")(merge4)
#conv4=BatchNormalization()(conv4)

up5=UpSampling2D(size=(2,2))(conv4)
up_conv5=Conv2D(10,(5,5),activation="relu",padding="same")(up5)
#up_conv5=BatchNormalization()(up_conv5)
merge5 = concatenate([conv1,up_conv5],axis=3)
conv5=Conv2D(10,(5,5),activation="relu",padding="same")(merge5)
#conv5=BatchNormalization()(conv5)

conv6 = Conv2D(1,(1,1),activation="relu")(conv5)
#conv6=BatchNormalization()(conv6)

model_1=Model(inputs=neural_input,outputs=conv6)
model_1.compile(optimizer="adam",loss="mean_squared_error")

model_1.fit(X_train,Y_train,validation_split=0.1,
          batch_size=100,epochs=50,verbose=1,callbacks=[mcp])
# Out:
# Train on 450 samples, validate on 50 samples
# Epoch 1/50
# 450/450 [==============================] - 3s 6ms/step - loss: 0.7173 - val_loss: 0.5250
# Epoch 2/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.2388 - val_loss: 0.1148
# Epoch 3/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0944 - val_loss: 0.0555
# Epoch 4/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0568 - val_loss: 0.0430
# Epoch 5/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0425 - val_loss: 0.0337
# Epoch 6/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0314 - val_loss: 0.0251
# Epoch 7/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0234 - val_loss: 0.0192
# Epoch 8/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0186 - val_loss: 0.0149
# Epoch 9/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0147 - val_loss: 0.0117
# Epoch 10/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0094
# Epoch 11/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0097 - val_loss: 0.0081
# Epoch 12/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0083 - val_loss: 0.0069
# Epoch 13/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 14/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 15/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 16/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 17/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 18/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 19/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 20/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 21/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 22/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 23/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 24/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 25/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 26/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 27/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 28/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 29/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 30/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 31/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 32/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 33/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 9.6945e-04
# Epoch 34/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 9.2296e-04
# Epoch 35/50
# 450/450 [==============================] - 1s 2ms/step - loss: 0.0010 - val_loss: 8.8186e-04
# Epoch 36/50
# 450/450 [==============================] - 1s 2ms/step - loss: 9.7514e-04 - val_loss: 8.3715e-04
# Epoch 37/50
# 450/450 [==============================] - 1s 2ms/step - loss: 9.3047e-04 - val_loss: 7.9975e-04
# Epoch 38/50
# 450/450 [==============================] - 1s 2ms/step - loss: 8.8957e-04 - val_loss: 7.6521e-04
# Epoch 39/50
# 450/450 [==============================] - 1s 2ms/step - loss: 8.5222e-04 - val_loss: 7.3458e-04
# Epoch 40/50
# 450/450 [==============================] - 1s 2ms/step - loss: 8.1733e-04 - val_loss: 7.0531e-04
# Epoch 41/50
# 450/450 [==============================] - 1s 2ms/step - loss: 7.8409e-04 - val_loss: 6.7689e-04
# Epoch 42/50
# 450/450 [==============================] - 1s 2ms/step - loss: 7.5411e-04 - val_loss: 6.5063e-04
# Epoch 43/50
# 450/450 [==============================] - 1s 2ms/step - loss: 7.2409e-04 - val_loss: 6.2650e-04
# Epoch 44/50
# 450/450 [==============================] - 1s 2ms/step - loss: 6.9814e-04 - val_loss: 6.0635e-04
# Epoch 45/50
# 450/450 [==============================] - 1s 2ms/step - loss: 6.7511e-04 - val_loss: 5.8695e-04
# Epoch 46/50
# 450/450 [==============================] - 1s 2ms/step - loss: 6.5245e-04 - val_loss: 5.6796e-04
# Epoch 47/50
# 450/450 [==============================] - 1s 2ms/step - loss: 6.3232e-04 - val_loss: 5.5192e-04
# Epoch 48/50
# 450/450 [==============================] - 1s 2ms/step - loss: 6.1325e-04 - val_loss: 5.3464e-04
# Epoch 49/50
# 450/450 [==============================] - 1s 2ms/step - loss: 5.9408e-04 - val_loss: 5.1969e-04
# Epoch 50/50
# 450/450 [==============================] - 1s 2ms/step - loss: 5.7803e-04 - val_loss: 5.0586e-04

# %% [markdown]
# You can access to the training model using this line.

# %%
[X_test, Y_test] = generate_test_set_denoising(verbose=False)
# Out:
# Creating data:

# %%
X_test=X_test.reshape(X_test.shape[0],72,72,1)
Y_test=Y_test.reshape(Y_test.shape[0],72,72,1)

# %% [markdown]
# This architecture gets  values of 8e-4 of the mean_squared_loss function in the test set and we can see in the fictures how it eliminates noise from the images efficiently.

# %%
model_1.evaluate(X_test,Y_test,verbose=2)
# Out:
# 0.0005734866733352344

# %%
Y_predict_1=model_1.predict(X_test)

# %%
fig=plt.figure(figsize=(10,30))
for i in range(5):
    plt.subplot(5, 3,3*i+1)
    plt.imshow(X_test[i].reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
    plt.subplot(5, 3,3*i+2)
    plt.imshow(Y_predict_1[i].reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
    plt.subplot(5, 3,3*i+3)
    plt.imshow(Y_test[i].reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')

# %% [markdown]
# In a second model, I tried to predict whether the pixel was black of white and I performed image segmentation based on the previous hourglass architecture, without Batchnormalization, but in this case I added an adittional block of convolutional networks with 2 convolutional networks with 80 filters. I also changed the concatenation order. Now, I concatenated each Upsampling with the previous convolutional network of the same dimension.  As the approach changed, the final network returns the probability of being white or black and the loss function is the binary crosss entropy.

# %%
mcp = ModelCheckpoint('denoising_model_2.hdf5', monitor="val_loss",
                      save_best_only=True, save_weights_only=False)

neural_input=Input((72,72,1))

conv1=Conv2D(10,(5,5),activation="relu",padding="same")(neural_input)
conv1=Conv2D(10,(5,5),activation="relu",padding="same")(conv1)
pool1=MaxPooling2D(pool_size=(2,2))(conv1)

conv2=Conv2D(20,(5,5),activation="relu",padding="same")(pool1)
conv2=Conv2D(20,(5,5),activation="relu",padding="same")(conv2)
pool2=MaxPooling2D(pool_size=(2,2))(conv2)

conv3=Conv2D(40,(5,5),activation="relu",padding="same")(pool2)
conv3=Conv2D(40,(5,5),activation="relu",padding="same")(conv3)
pool3=MaxPooling2D(pool_size=(2,2))(conv3)

conv4=Conv2D(80,(5,5),activation="relu",padding="same")(pool3)
conv4=Conv2D(80,(5,5),activation="relu",padding="same")(conv4)

up5=UpSampling2D(size=(2,2))(conv4)
merge5 = concatenate([conv3,up5],axis=3)

conv5=Conv2D(40,(5,5),activation="relu",padding="same")(merge5)
conv5=Conv2D(40,(5,5),activation="relu",padding="same")(conv5)

up6=UpSampling2D(size=(2,2))(conv5)
merge6 = concatenate([conv2,up6],axis=3)

conv6=Conv2D(20,(5,5),activation="relu",padding="same")(merge6)
conv6=Conv2D(20,(5,5),activation="relu",padding="same")(conv6)

up7=UpSampling2D(size=(2,2))(conv6)
merge7 = concatenate([conv1,up7],axis=3)

conv7=Conv2D(10,(5,5),activation="relu",padding="same")(merge7)
conv7=Conv2D(10,(5,5),activation="relu",padding="same")(conv7)

conv8 = Conv2D(1,(1,1),activation="sigmoid")(conv7)
model_cross_entropy=Model(inputs=neural_input,outputs=conv8)
model_cross_entropy.compile(loss='binary_crossentropy',
              metrics=['accuracy'],
              optimizer='adam')
model_cross_entropy.fit(X_train,Y_train,validation_split=0.1,
          batch_size=100,epochs=100,verbose=2,callbacks=[mcp])
# Out:
# Train on 450 samples, validate on 50 samples
# Epoch 1/100
#  - 3s - loss: 0.6950 - acc: 0.4567 - val_loss: 0.5315 - val_acc: 0.9060
# Epoch 2/100
#  - 1s - loss: 0.4453 - acc: 0.9016 - val_loss: 0.3411 - val_acc: 0.9100
# Epoch 3/100
#  - 1s - loss: 0.2822 - acc: 0.9027 - val_loss: 0.2083 - val_acc: 0.9100
# Epoch 4/100
#  - 1s - loss: 0.2060 - acc: 0.9027 - val_loss: 0.1651 - val_acc: 0.9100
# Epoch 5/100
#  - 1s - loss: 0.1686 - acc: 0.9027 - val_loss: 0.1479 - val_acc: 0.9100
# Epoch 6/100
#  - 1s - loss: 0.1495 - acc: 0.9027 - val_loss: 0.1249 - val_acc: 0.9100
# Epoch 7/100
#  - 1s - loss: 0.1252 - acc: 0.9027 - val_loss: 0.1034 - val_acc: 0.9100
# Epoch 8/100
#  - 1s - loss: 0.1063 - acc: 0.9027 - val_loss: 0.0846 - val_acc: 0.9100
# Epoch 9/100
#  - 1s - loss: 0.0881 - acc: 0.9027 - val_loss: 0.0772 - val_acc: 0.9100
# Epoch 10/100
#  - 1s - loss: 0.0794 - acc: 0.9029 - val_loss: 0.0716 - val_acc: 0.9369
# Epoch 11/100
#  - 1s - loss: 0.0747 - acc: 0.9540 - val_loss: 0.0649 - val_acc: 0.9738
# Epoch 12/100
#  - 1s - loss: 0.0665 - acc: 0.9802 - val_loss: 0.0531 - val_acc: 0.9875
# Epoch 13/100
#  - 1s - loss: 0.0526 - acc: 0.9854 - val_loss: 0.0345 - val_acc: 0.9876
# Epoch 14/100
#  - 1s - loss: 0.0325 - acc: 0.9846 - val_loss: 0.0235 - val_acc: 0.9868
# Epoch 15/100
#  - 1s - loss: 0.0241 - acc: 0.9847 - val_loss: 0.0238 - val_acc: 0.9839
# Epoch 16/100
#  - 1s - loss: 0.0216 - acc: 0.9844 - val_loss: 0.0152 - val_acc: 0.9879
# Epoch 17/100
#  - 1s - loss: 0.0182 - acc: 0.9854 - val_loss: 0.0173 - val_acc: 0.9875
# Epoch 18/100
#  - 1s - loss: 0.0176 - acc: 0.9859 - val_loss: 0.0132 - val_acc: 0.9882
# Epoch 19/100
#  - 1s - loss: 0.0157 - acc: 0.9862 - val_loss: 0.0129 - val_acc: 0.9882
# Epoch 20/100
#  - 1s - loss: 0.0147 - acc: 0.9864 - val_loss: 0.0133 - val_acc: 0.9882
# Epoch 21/100
#  - 1s - loss: 0.0142 - acc: 0.9865 - val_loss: 0.0122 - val_acc: 0.9884
# Epoch 22/100
#  - 1s - loss: 0.0135 - acc: 0.9868 - val_loss: 0.0107 - val_acc: 0.9885
# Epoch 23/100
#  - 1s - loss: 0.0126 - acc: 0.9871 - val_loss: 0.0103 - val_acc: 0.9885
# Epoch 24/100
#  - 1s - loss: 0.0121 - acc: 0.9872 - val_loss: 0.0100 - val_acc: 0.9886
# Epoch 25/100
#  - 1s - loss: 0.0117 - acc: 0.9872 - val_loss: 0.0098 - val_acc: 0.9886
# Epoch 26/100
#  - 1s - loss: 0.0114 - acc: 0.9873 - val_loss: 0.0095 - val_acc: 0.9886
# Epoch 27/100
#  - 1s - loss: 0.0111 - acc: 0.9873 - val_loss: 0.0093 - val_acc: 0.9886
# Epoch 28/100
#  - 1s - loss: 0.0108 - acc: 0.9874 - val_loss: 0.0090 - val_acc: 0.9887
# Epoch 29/100
#  - 1s - loss: 0.0106 - acc: 0.9874 - val_loss: 0.0088 - val_acc: 0.9887
# Epoch 30/100
#  - 1s - loss: 0.0104 - acc: 0.9874 - val_loss: 0.0088 - val_acc: 0.9887
# Epoch 31/100
#  - 1s - loss: 0.0102 - acc: 0.9874 - val_loss: 0.0084 - val_acc: 0.9888
# Epoch 32/100
#  - 1s - loss: 0.0100 - acc: 0.9875 - val_loss: 0.0084 - val_acc: 0.9888
# Epoch 33/100
#  - 1s - loss: 0.0098 - acc: 0.9875 - val_loss: 0.0081 - val_acc: 0.9888
# Epoch 34/100
#  - 1s - loss: 0.0096 - acc: 0.9875 - val_loss: 0.0080 - val_acc: 0.9888
# Epoch 35/100
#  - 1s - loss: 0.0094 - acc: 0.9875 - val_loss: 0.0078 - val_acc: 0.9889
# Epoch 36/100
#  - 1s - loss: 0.0093 - acc: 0.9875 - val_loss: 0.0078 - val_acc: 0.9889
# Epoch 37/100
#  - 1s - loss: 0.0091 - acc: 0.9876 - val_loss: 0.0076 - val_acc: 0.9889
# Epoch 38/100
#  - 1s - loss: 0.0090 - acc: 0.9876 - val_loss: 0.0075 - val_acc: 0.9890
# Epoch 39/100
#  - 1s - loss: 0.0088 - acc: 0.9876 - val_loss: 0.0074 - val_acc: 0.9889
# Epoch 40/100
#  - 1s - loss: 0.0087 - acc: 0.9876 - val_loss: 0.0073 - val_acc: 0.9890
# Epoch 41/100
#  - 1s - loss: 0.0085 - acc: 0.9876 - val_loss: 0.0072 - val_acc: 0.9890
# Epoch 42/100
#  - 1s - loss: 0.0085 - acc: 0.9876 - val_loss: 0.0072 - val_acc: 0.9890
# Epoch 43/100
#  - 1s - loss: 0.0084 - acc: 0.9876 - val_loss: 0.0071 - val_acc: 0.9890
# Epoch 44/100
#  - 1s - loss: 0.0083 - acc: 0.9876 - val_loss: 0.0069 - val_acc: 0.9891
# Epoch 45/100
#  - 1s - loss: 0.0081 - acc: 0.9877 - val_loss: 0.0068 - val_acc: 0.9891
# Epoch 46/100
#  - 1s - loss: 0.0081 - acc: 0.9877 - val_loss: 0.0068 - val_acc: 0.9891
# Epoch 47/100
#  - 1s - loss: 0.0079 - acc: 0.9877 - val_loss: 0.0067 - val_acc: 0.9891
# Epoch 48/100
#  - 1s - loss: 0.0078 - acc: 0.9877 - val_loss: 0.0067 - val_acc: 0.9890
# Epoch 49/100
#  - 1s - loss: 0.0078 - acc: 0.9877 - val_loss: 0.0066 - val_acc: 0.9891
# Epoch 50/100
#  - 1s - loss: 0.0077 - acc: 0.9877 - val_loss: 0.0066 - val_acc: 0.9891
# Epoch 51/100
#  - 1s - loss: 0.0077 - acc: 0.9877 - val_loss: 0.0065 - val_acc: 0.9891
# Epoch 52/100
#  - 1s - loss: 0.0076 - acc: 0.9877 - val_loss: 0.0065 - val_acc: 0.9891
# Epoch 53/100
#  - 1s - loss: 0.0075 - acc: 0.9877 - val_loss: 0.0064 - val_acc: 0.9892
# Epoch 54/100
#  - 1s - loss: 0.0074 - acc: 0.9877 - val_loss: 0.0063 - val_acc: 0.9891
# Epoch 55/100
#  - 1s - loss: 0.0074 - acc: 0.9877 - val_loss: 0.0063 - val_acc: 0.9891
# Epoch 56/100
#  - 1s - loss: 0.0073 - acc: 0.9877 - val_loss: 0.0063 - val_acc: 0.9891
# Epoch 57/100
#  - 1s - loss: 0.0073 - acc: 0.9877 - val_loss: 0.0062 - val_acc: 0.9891
# Epoch 58/100
#  - 1s - loss: 0.0072 - acc: 0.9877 - val_loss: 0.0062 - val_acc: 0.9891
# Epoch 59/100
#  - 1s - loss: 0.0072 - acc: 0.9877 - val_loss: 0.0062 - val_acc: 0.9892
# Epoch 60/100
#  - 1s - loss: 0.0072 - acc: 0.9878 - val_loss: 0.0061 - val_acc: 0.9891
# Epoch 61/100
#  - 1s - loss: 0.0071 - acc: 0.9878 - val_loss: 0.0061 - val_acc: 0.9891
# Epoch 62/100
#  - 1s - loss: 0.0071 - acc: 0.9878 - val_loss: 0.0061 - val_acc: 0.9892
# Epoch 63/100
#  - 1s - loss: 0.0071 - acc: 0.9878 - val_loss: 0.0061 - val_acc: 0.9893
# Epoch 64/100
#  - 1s - loss: 0.0070 - acc: 0.9878 - val_loss: 0.0060 - val_acc: 0.9892
# Epoch 65/100
#  - 1s - loss: 0.0071 - acc: 0.9878 - val_loss: 0.0061 - val_acc: 0.9891
# Epoch 66/100
#  - 1s - loss: 0.0070 - acc: 0.9878 - val_loss: 0.0060 - val_acc: 0.9893
# Epoch 67/100
#  - 1s - loss: 0.0070 - acc: 0.9878 - val_loss: 0.0060 - val_acc: 0.9892
# Epoch 68/100
#  - 1s - loss: 0.0069 - acc: 0.9878 - val_loss: 0.0060 - val_acc: 0.9893
# Epoch 69/100
#  - 1s - loss: 0.0069 - acc: 0.9878 - val_loss: 0.0060 - val_acc: 0.9894
# Epoch 70/100
#  - 1s - loss: 0.0070 - acc: 0.9878 - val_loss: 0.0060 - val_acc: 0.9892
# Epoch 71/100
#  - 1s - loss: 0.0069 - acc: 0.9878 - val_loss: 0.0060 - val_acc: 0.9894
# Epoch 72/100
#  - 1s - loss: 0.0069 - acc: 0.9879 - val_loss: 0.0059 - val_acc: 0.9892
# Epoch 73/100
#  - 1s - loss: 0.0068 - acc: 0.9878 - val_loss: 0.0059 - val_acc: 0.9894
# Epoch 74/100
#  - 1s - loss: 0.0068 - acc: 0.9879 - val_loss: 0.0059 - val_acc: 0.9893
# Epoch 75/100
#  - 1s - loss: 0.0068 - acc: 0.9879 - val_loss: 0.0059 - val_acc: 0.9894
# Epoch 76/100
#  - 1s - loss: 0.0068 - acc: 0.9879 - val_loss: 0.0058 - val_acc: 0.9893
# Epoch 77/100
#  - 1s - loss: 0.0067 - acc: 0.9879 - val_loss: 0.0059 - val_acc: 0.9893
# Epoch 78/100
#  - 1s - loss: 0.0068 - acc: 0.9879 - val_loss: 0.0059 - val_acc: 0.9894
# Epoch 79/100
#  - 1s - loss: 0.0067 - acc: 0.9879 - val_loss: 0.0058 - val_acc: 0.9893
# Epoch 80/100
#  - 1s - loss: 0.0067 - acc: 0.9879 - val_loss: 0.0058 - val_acc: 0.9894
# Epoch 81/100
#  - 1s - loss: 0.0067 - acc: 0.9879 - val_loss: 0.0058 - val_acc: 0.9893
# Epoch 82/100
#  - 1s - loss: 0.0067 - acc: 0.9879 - val_loss: 0.0058 - val_acc: 0.9894
# Epoch 83/100
#  - 1s - loss: 0.0067 - acc: 0.9879 - val_loss: 0.0058 - val_acc: 0.9894
# Epoch 84/100
#  - 1s - loss: 0.0066 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 85/100
#  - 1s - loss: 0.0066 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 86/100
#  - 1s - loss: 0.0066 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 87/100
#  - 1s - loss: 0.0066 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 88/100
#  - 1s - loss: 0.0066 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 89/100
#  - 1s - loss: 0.0066 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 90/100
#  - 1s - loss: 0.0065 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 91/100
#  - 1s - loss: 0.0065 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 92/100
#  - 1s - loss: 0.0065 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 93/100
#  - 1s - loss: 0.0065 - acc: 0.9879 - val_loss: 0.0056 - val_acc: 0.9894
# Epoch 94/100
#  - 1s - loss: 0.0065 - acc: 0.9879 - val_loss: 0.0056 - val_acc: 0.9894
# Epoch 95/100
#  - 1s - loss: 0.0065 - acc: 0.9879 - val_loss: 0.0056 - val_acc: 0.9894
# Epoch 96/100
#  - 1s - loss: 0.0065 - acc: 0.9879 - val_loss: 0.0056 - val_acc: 0.9894
# Epoch 97/100
#  - 1s - loss: 0.0065 - acc: 0.9879 - val_loss: 0.0056 - val_acc: 0.9894
# Epoch 98/100
#  - 1s - loss: 0.0065 - acc: 0.9879 - val_loss: 0.0057 - val_acc: 0.9894
# Epoch 99/100
#  - 1s - loss: 0.0064 - acc: 0.9879 - val_loss: 0.0056 - val_acc: 0.9894
# Epoch 100/100
#  - 1s - loss: 0.0064 - acc: 0.9879 - val_loss: 0.0056 - val_acc: 0.9894

# %% [markdown]
# The performance of this architecture is also satisfying, getting an accuracy of  almost  99% in the test set.
# As mentioned before, the results show the probability of each pixel of being white of black. In this model, the figures are more friendly to the human eye, as the fond is white.

# %%
model_cross_entropy.evaluate(X_test,Y_test,verbose=2)
# Out:
# [0.005975039917975664, 0.9891107265154521]

# %%
Y_predict_2=model_cross_entropy.predict(X_test)

# %%
fig=plt.figure(figsize=(10,30))
for i in range(5):
    plt.subplot(5, 3,3*i+1)
    plt.imshow(X_test[i].reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
    plt.subplot(5, 3,3*i+2)
    plt.imshow(Y_predict_2[i].reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
    plt.subplot(5, 3,3*i+3)
    plt.imshow(Y_test[i].reshape(IMAGE_SIZE,IMAGE_SIZE), cmap='gray')
